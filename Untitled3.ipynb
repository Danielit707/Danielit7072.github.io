# %%
import pandas as pd

# %%
archivo_csv = 'Zonas_Wi-Fi.csv'

# %%
df = pd.read_csv(archivo_csv)

# %%
print(df.to_string())
# Out:
#      TIPO IDENTIFICACION  NUMERO IDENTIFICACION            RAZON SOCIAL  MUNICIPIO_COD             NOMBRE_MUNICIPIO  DEPARTAMENTO_COD NOMBRE_DEPARTAMENTO ESTADO EMPRESA  COD INTERNO AREA NATURALEZA FECHA CORTE  ID INDICADOR FECHA VIGENCIA  META
# 0         ID-ZW - FASE 2             7610905002            Buenaventura          76109                 BUENAVENTURA                76     VALLE DEL CAUCA         ACTIVO               NaN    PUBLICA  2017-12-31          4900     2017-12-31   300
# 1         ID-ZW - FASE 2             4755505001                   Plato          47555                        PLATO                47           MAGDALENA         ACTIVO               NaN    PUBLICA  2017-12-31          4900     2017-12-31   300
# 2         ID-ZW - FASE 2             1980702001                  Timbio          19807                       TIMBIO                19               CAUCA         ACTIVO               NaN    PUBLICA  2016-12-31          4198     2016-12-31   250
# ...
